# %% [markdown]
# # Random
# ### Goal
# - Learn to use Random
# - This enables us to create simple games

# %%
import random

# %%
random.randint(1, 6)

# %%
a = random.randint(1, 6)

# %%
a

# %%
random.uniform(0, 1)

# %%
random.gauss(0, 1)
