# %% [markdown]
# # Random
# ### Goal
# - Learn to use Random
# - This enables us to create simple games

# %%
import random

# %%
random.randint(1, 6)
# Out:
# 2

# %%
a = random.randint(1, 6)
a
# Out:
# 3

# %%
random.uniform(0, 1)
# Out:
# 0.12500220072551294

# %%
random.gauss(0, 1)
# Out:
# -1.1291709893952773
