# %% [markdown]
# # Loops
# ### Goal
# - Learn how to iterate over lists
# - Iterate over the chars in a string
# - Create a for-loop over a range
# - Create a while-loop

# %% [markdown]
# ### A few new things
